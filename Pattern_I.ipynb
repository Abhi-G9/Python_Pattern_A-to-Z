# %%
def I():
    for row in range(7):
        for col in range(6):
            if (col==5 and( row!=0 or row!=2))or ((row==0 or row==6 ) and (col>0)):
                print("*",end=' ')
            else:
                print('',end=' ')
        print()
I()
# Out:
#  * * * * *
#      *
#      *
#      *
#      *
#      *
#  * * * * *
