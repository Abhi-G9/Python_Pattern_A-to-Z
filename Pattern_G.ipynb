# %%
def G():
    for row in range(7):
        for col in range(7):
            if (col==0 and(row!=6)) or (col==4 and (row!=1 and row!= 2 and row!=6))or(col==6 and row!=1 and row!=2 and row!=3 and row!=6 and row!=0 and row!=5)or((row==0 or row==5 )and(col>0 and col<4))or (row==3 and (col==4 or col==5 or col==6)):
                print("*",end=' ')
            else:
                print(' ',end=' ')
        print()
G()
# Out:
# * * * * *
# *
# *
# *       * * *
# *       *   *
# * * * * *
