# %%
def J():

    for row in range(7):
        for col in range(5):
            if (col==3 and(row!=0 or row!=1 ))or(col==0 and(row!=0 and row!=1 and row!=2 and row!=3)) or(row==0 or row==6 and col<4):
                print('*',end=' ')
            else:
                print(' ',end=' ')
        print()
J()
# Out:
# * * * * *
#       *
#       *
#       *
# *     *
# *     *
# * * * *
